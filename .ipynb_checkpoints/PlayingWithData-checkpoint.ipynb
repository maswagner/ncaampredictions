# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('TeamRecords.csv')

# %%
data.head()
# Out:
#    Rk             School             City State  From    To  Yrs     G     W  \
# 0   1  Abilene Christian          Abilene Texas  1971  2023   13   366   200
# 1   2          Air Force  USAF Academy Colorado  1958  2023   66  1787   775
# 2   3              Akron             Akron Ohio  1902  2023   72  1656   984
# 3   4            Alabama     Tuscaloosa Alabama  1913  2023  110  2829  1744
# 4   5        Alabama A&M         Normal Alabama  2000  2023   24   661   251
#
#       L   W-L%    SRS    SOS  AP  CREG  CTRN  NCAA   FF   NC
# 0   166  0.546  -8.68  -6.38   0     0     2   2.0  0.0  0.0
# 1  1012  0.434  -2.87   1.17   0     1     0   4.0  0.0  0.0
# 2   672  0.594  -0.05  -1.35   0     9     5   5.0  0.0  0.0
# 3  1084  0.617   7.81   4.85  16    11     8  23.0  0.0  0.0
# 4   410  0.380 -16.82 -11.04   0     1     1   1.0  0.0  0.0

# %%
data.isna().sum()
# Out:
# Rk             0
# School         0
# City State     0
# From           0
# To             0
# Yrs            0
# G              0
# W              0
# L              0
# W-L%           0
# SRS           97
# SOS           97
# AP             0
# CREG           0
# CTRN           0
# NCAA          81
# FF            81
# NC            81
# dtype: int64

# %%
data = data.dropna()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 393 entries, 0 to 489
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Rk          393 non-null    int64
#  1   School      393 non-null    object
#  2   City State  393 non-null    object
#  3   From        393 non-null    int64
#  4   To          393 non-null    int64
#  5   Yrs         393 non-null    int64
#  6   G           393 non-null    int64
#  7   W           393 non-null    int64
#  8   L           393 non-null    int64
#  9   W-L%        393 non-null    float64
#  10  SRS         393 non-null    float64
#  11  SOS         393 non-null    float64
#  12  AP          393 non-null    int64
#  13  CREG        393 non-null    int64
#  14  CTRN        393 non-null    int64
#  15  NCAA        393 non-null    float64
#  16  FF          393 non-null    float64
#  17  NC          393 non-null    float64
# dtypes: float64(6), int64(10), object(2)
# memory usage: 58.3+ KB

# %%
data['School'] = data['School'].str.replace(' ', '')
data['School'] = data['School'].str.lower()
data
# Out:
#       Rk            School             City State  From    To  Yrs     G  \
# 0      1  abilenechristian          Abilene Texas  1971  2023   13   366
# 1      2          airforce  USAF Academy Colorado  1958  2023   66  1787
# 2      3             akron             Akron Ohio  1902  2023   72  1656
# 3      4           alabama     Tuscaloosa Alabama  1913  2023  110  2829
# 4      5        alabamaa&m         Normal Alabama  2000  2023   24   661
# ..   ...               ...                    ...   ...   ...  ...   ...
# 485  486       wrightstate            Dayton Ohio  1988  2023   36  1070
# 486  487           wyoming        Laramie Wyoming  1905  2023  118  2819
# 487  488            xavier        Cincinnati Ohio  1920  2023  102  2633
# 488  489              yale  New Haven Connecticut  1896  2023  128  3029
# 489  490   youngstownstate        Youngstown Ohio  1948  2023   43  1233
#
#         W     L   W-L%    SRS    SOS  AP  CREG  CTRN  NCAA   FF   NC
# 0     200   166  0.546  -8.68  -6.38   0     0     2   2.0  0.0  0.0
# 1     775  1012  0.434  -2.87   1.17   0     1     0   4.0  0.0  0.0
# 2     984   672  0.594  -0.05  -1.35   0     9     5   5.0  0.0  0.0
# 3    1744  1084  0.617   7.81   4.85  16    11     8  23.0  0.0  0.0
# 4     251   410  0.380 -16.82 -11.04   0     1     1   1.0  0.0  0.0
# ..    ...   ...    ...    ...    ...  ..   ...   ...   ...  ...  ...
# 485   600   470  0.561  -1.30  -2.55   0     4     4   4.0  0.0  0.0
# 486  1588  1231  0.563   2.68   2.59   4    21     3  16.0  1.0  1.0
# 487  1572  1061  0.597   5.96   3.87  12    18     9  28.0  0.0  0.0
# 488  1527  1499  0.505  -6.10  -4.54   1    15     2   6.0  0.0  0.0
# 489   489   744  0.397  -8.12  -3.45   0     0     0   0.0  0.0  0.0
#
# [393 rows x 18 columns]

# %%
plt.scatter(data['W'], data['L'])
plt.title('Wins vs Losses')
plt.xlabel('Wins')
plt.ylabel('Losses')
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(12,4))

axes[0].hist(data['W-L%'], bins='auto')
axes[0].set_title('Win to Loss Percentage')
axes[0].set_xlabel('W/L Percentage')

axes[1].scatter(data['W-L%'], data['SRS'])
axes[1].set_title('Strength of Schedule by W/L Ratio')
axes[1].set_xlabel('W/L Ratio')
axes[1].set_ylabel('SRS')
# Out:
# Text(0, 0.5, 'SRS')

# %%
curdata = pd.read_csv('TeamPoints.csv')

# %%
plt.scatter(curdata['PPG'], curdata['OPP PPG'])
plt.xlabel('PPG')
plt.ylabel('OPP PPG')
# Out:
# Text(0, 0.5, 'OPP PPG')

# %%
curdata['PTDif'] = curdata['PPG'] - curdata['OPP PPG']

# %%
curdata.sort_values(by='PPG', ascending=False)
# Out:
#                   Team  GM  PTS   PPG  OPP PTS  OPP PPG  PTDif
# 11            Arizona    6  585  97.5      472     78.7   18.8
# 29             Bryant    7  670  95.7      483     69.0   26.7
# 295               UAB    6  565  94.2      415     69.2   25.0
# 171          Missouri    7  653  93.3      491     70.1   23.2
# 127     James Madison    8  743  92.9      502     62.8   30.1
# ..                 ...  ..  ...   ...      ...      ...    ...
# 277       Stony Brook    6  350  58.3      448     74.7  -16.4
# 123             IUPUI    7  405  57.9      528     75.4  -17.5
# 103         Green Bay    6  341  56.8      466     77.7  -20.9
# 169  Mississippi Val.    8  444  55.5      632     79.0  -23.5
# 86        Florida A&M    5  273  54.6      383     76.6  -22.0
#
# [352 rows x 7 columns]

# %%
curdata['Team'] = curdata['Team'].str.replace(' ', '')
curdata['Team'] = curdata['Team'].str.lower()
curdata
# Out:
#                   Team  GM  PTS   PPG  OPP PTS  OPP PPG  PTDif
# 0    a&m-corpuschristi   7  535  76.4      478     68.3    8.1
# 1     abilenechristian   7  512  73.1      491     70.1    3.0
# 2             airforce   7  459  65.6      433     61.9    3.7
# 3                akron   6  388  64.7      400     66.7   -2.0
# 4           alabamaa&m   7  535  76.4      558     79.7   -3.3
# ..                 ...  ..  ...   ...      ...      ...    ...
# 347          wrightst.   7  578  82.6      497     71.0   11.6
# 348            wyoming   6  435  72.5      404     67.3    5.2
# 349             xavier   7  577  82.4      525     75.0    7.4
# 350               yale   7  559  79.9      375     53.6   26.3
# 351      youngstownst.   7  587  83.9      507     72.4   11.5
#
# [352 rows x 7 columns]

# %%
curdata[curdata['Team'] == 'arizona']
# Out:
#        Team  GM  PTS   PPG  OPP PTS  OPP PPG  PTDif  RandomScore  \
# 11  arizona   6  585  97.5      472     78.7   18.8        104.5
#
#     OPPRandomScore
# 11            70.7

# %%
team1 = input('Select a team: ')
team1 = team1.lower()

def findteam(team):
    plt.figure(figsize=(12,10))

    for i in range(1,10):
        curdata['RandomScore'] = curdata['PPG']+random.randint(-10,10)
        curdata['OPPRandomScore'] = curdata['OPP PPG']+random.randint(-10,10)
        plt.scatter(i, (curdata[curdata['Team'] == team]['RandomScore']), c='darkblue')
        plt.scatter(i, (curdata[curdata['Team'] == team]['OPPRandomScore']), c='darkred')
    plt.axhline(y = float(curdata[curdata['Team'] == team]['PPG']), label='Average PPG')
    plt.axhline(y = float(curdata[curdata['Team'] == team]['OPP PPG']), color='red', label='Average OPP PPG')
    plt.title(team.title() + ' Random Points over 10 games')
    plt.legend()
    plt.xlabel('Number of games played')
    plt.ylabel('Total points scored by '+ team.title())

findteam(team1)
# Out:
# Select a team: arizona

# %%
def findanteam(team):
    return data[data['School'] == team]

findanteam('arizona')
# Out:
#     Rk   School      City State  From    To  Yrs     G     W    L   W-L%  \
# 12  13  arizona  Tucson Arizona  1905  2023  116  2823  1864  958  0.661
#
#      SRS   SOS  AP  CREG  CTRN  NCAA   FF   NC
# 12  9.37  5.09  28    25     8  36.0  4.0  1.0

# %%
findanteam('utah')
# Out:
#       Rk School           City State  From    To  Yrs     G     W     L  \
# 433  434   utah  Salt Lake City Utah  1909  2023  115  2917  1863  1054
#
#       W-L%   SRS   SOS  AP  CREG  CTRN  NCAA   FF   NC
# 433  0.639  8.29  3.76  21    30     5  29.0  4.0  1.0
